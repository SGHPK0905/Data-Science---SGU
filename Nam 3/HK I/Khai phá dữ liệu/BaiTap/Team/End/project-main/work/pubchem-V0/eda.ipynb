# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor

df = pd.read_csv('melting_point_features.csv')

y = df['Tm']
X = df.drop(columns=['Tm'])

X = X.select_dtypes(include=[np.number])

imputer = SimpleImputer(strategy='median')
X_clean = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

X_train, X_test, y_train, y_test = train_test_split(X_clean, y, test_size=0.2, random_state=42)

base_model = LGBMRegressor(random_state=42, n_jobs=-1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       3 from sklearn.impute import SimpleImputer
#       4 from sklearn.model_selection import train_test_split
# ----> 5 from lightgbm import LGBMRegressor
#       7 df = pd.read_csv('melting_point_features.csv')
#       9 # 2. Tách biến mục tiêu (y) và đặc trưng (X)
#      10 # Giả sử cột mục tiêu là 'Tm' (Nhiệt độ nóng chảy)
#
# ModuleNotFoundError: No module named 'lightgbm'
